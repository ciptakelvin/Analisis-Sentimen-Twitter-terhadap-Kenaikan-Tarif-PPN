# %%
import snscrape.modules.twitter as sns
import tweepy
import pandas as pd
import os
from datetime import datetime
from IPython.display import clear_output


def initialize():
    #API Initialization
    global api_key,api_secret,bearer_token,access_token,token_secret
    api_key=os.environ['T_API_KEY']
    api_secret=os.environ['T_API_SECRET']
    bearer_token=os.environ['T_BEARER_TOKEN']
    access_token=os.environ['T_ACCESS_TOKEN']
    token_secret=os.environ['T_TOKEN_SECRET']

def auth_handler():
    #API Auth
    global auth,api
    auth = tweepy.OAuthHandler(api_key, api_secret)
    auth.set_access_token(access_token, token_secret)
    api = tweepy.API(auth, wait_on_rate_limit=True)

def pull(keyword:str,limit:int)->pd.DataFrame:
    #Tweet Pull
    print(keyword," is processing..")
    r=_sns_pull(keyword,limit)
    clear_output()
    return r

def _sns_pull(keyword,limit):
    tweet=[]
    for i, t in enumerate(sns.TwitterSearchScraper(keyword).get_items()):
        clear_output()
        print(keyword," processing tweet("+str(i)+")...")
        if i>=limit:
            break;
        
        tweet.append([t.id,keyword,t.url,t.date,t.rawContent,None,t.user.username,int(t.viewCount) if t.viewCount else 0,t.replyCount,t.retweetCount,t.likeCount,t.quoteCount,t.lang,t.sourceLabel,t.coordinates.latitude if t.coordinates else None,t.coordinates.longitude if t.coordinates else None,t.place.fullName if t.place else None,t.hashtags,t.inReplyToUser.username if t.inReplyToUser else None,len(t.mentionedUsers) if t.mentionedUsers else 0,[i.username for i in t.mentionedUsers] if t.mentionedUsers else None,t.user.verified,t.user.followersCount,t.user.statusesCount])
    return pd.DataFrame(tweet,columns=['Id','Search Keyword','URL','Datetime','Tweet','Sentiment Label','Username','View Count','Reply Count','Retweet Count','Like Count','Quote Count','Language','Source','Coordinates (Latitude)','Coordinates (Longitude)','Place','Hashtags','Reply to User','Mentioned Users Count','Mentioned Users','User Verified','User Followers Count','User Statuses Count'])

# def _tw_pull(keyword,limit)->pd.DataFrame:
#     tweet=[]
    
#     for i, t in enumerate(sns.TwitterSearchScraper(keyword).get_items()):
#         if i>=limit:
#             break;
#         tw=api.get_status(t.id)._json
#         tweet.append([t.id,keyword,t.url,t.date,t.rawContent,None,t.user.username,t.viewCount,t.replyCount,t.retweetCount,t.likeCount,t.quoteCount,t.lang,t.sourceLabel,t.coordinates.latitude if t.coordinates else None,t.coordinates.longitude if t.coordinates else None,t.place.fullName if t.place else None,t.hashtags,t.inReplyToUser.username if t.inReplyToUser else None,len(t.mentionedUsers) if t.mentionedUsers else 0,[i.username for i in t.mentionedUsers] if t.mentionedUsers else None,t.user.verified,t.user.followersCount,t.user.statusesCount])
#     return pd.DataFrame(tweet,columns=['Id','Search Keyword','URL','Datetime','Tweet','Sentiment Label','Username','View Count','Reply Count','Retweet Count','Like Count','Quote Count','Language','Source','Coordinates (Latitude)','Coordinates (Longitude)','Place','Hashtags','Reply to User','Mentioned Users Count','Mentioned Users','User Verified','User Followers Count','User Statuses Count'])

def multi_pull(data:list[pd.DataFrame])->pd.DataFrame:
    d=data[0]
    for k,i in enumerate(data):
        if k==0:
            continue
        d=pd.concat([d,i],ignore_index=True).copy()
    return d

#Initialization
initialize()
auth_handler()

#Setting
file_name="PPN Naik"
tweet_limit=1000000000
keywords=[
    "PPN Naik",
    "PPN 11%",
    "Kenaikan PPN",
    "Tarif baru PPN"
]

#Pull Tweet
data=multi_pull([pull(i,tweet_limit) for i in keywords])

#Save to CSV
data.to_csv(str(datetime.now()).replace(":",".")+" "+file_name+".csv",index=False)
print("File Saved")
data
# Out:
# File Saved
#                         Id  Search Keyword  \
# 0      1630518897362481153        PPN Naik
# 1      1630516734980669440        PPN Naik
# 2      1630503181120839682        PPN Naik
# 3      1630489345898708992        PPN Naik
# 4      1630486040556503041        PPN Naik
# ...                    ...             ...
# 49088          16667647720  Tarif baru PPN
# 49089          16667557518  Tarif baru PPN
# 49090          16667252573  Tarif baru PPN
# 49091           7671698988  Tarif baru PPN
# 49092           6075299212  Tarif baru PPN
#
#                                                      URL  \
# 0      https://twitter.com/Fakultas_meme/status/16305...
# 1      https://twitter.com/Nokomplen/status/163051673...
# 2      https://twitter.com/Aman47264904/status/163050...
# 3      https://twitter.com/buutiful_co/status/1630489...
# 4      https://twitter.com/rmbantencom/status/1630486...
# ...                                                  ...
# 49088     https://twitter.com/DonCess/status/16667647720
# 49089  https://twitter.com/BhanuAbhinawa/status/16667...
# 49090     https://twitter.com/pungkas/status/16667252573
# 49091    https://twitter.com/riwatigis/status/7671698988
# 49092   https://twitter.com/taribetari/status/6075299212
#
#                        Datetime  \
# 0     2023-02-28 10:42:53+00:00
# 1     2023-02-28 10:34:17+00:00
# 2     2023-02-28 09:40:26+00:00
# 3     2023-02-28 08:45:27+00:00
# 4     2023-02-28 08:32:19+00:00
# ...                         ...
# 49088 2010-06-21 04:05:52+00:00
# 49089 2010-06-21 04:04:15+00:00
# 49090 2010-06-21 03:59:05+00:00
# 49091 2010-01-12 15:11:04+00:00
# 49092 2009-11-26 07:17:53+00:00
#
#                                                    Tweet Sentiment Label  \
# 0      @txtdrimedia ketika L0Nte IMF menerbitkan glob...            None
# 1      Cook cook lah,,,, diampoot kabeehh!!! Kene ngo...            None
# 2      @OposisiCerdas Menurut anda aman??? tetapi efe...            None
# 3      Betul! My honeymoon masa tu negara still dlm f...            None
# 4      Pegawai Hidup Mewah, PPN, BBM Hingga Angka Kem...            None
# ...                                                  ...             ...
# 49088  RT @pungkas: BlackBerry Internet Service @XL12...            None
# 49089  RT @pungkas: BlackBerry Internet Service @XL12...            None
# 49090  BlackBerry Internet Service @XL123 turun tarif...            None
# 49091  wah tuh tarif PPN yang baru ya? RT @vietaanggr...            None
# 49092  Bnr2 tarif PPN.hahaRT @@chitraayu: @Tarrrriiii...            None
#
#             Username  View Count  Reply Count  Retweet Count  ...  \
# 0      Fakultas_meme          24            0              0  ...
# 1          Nokomplen           3            0              0  ...
# 2       Aman47264904           2            0              0  ...
# 3        buutiful_co          54            0              0  ...
# 4        rmbantencom          23            0              0  ...
# ...              ...         ...          ...            ...  ...
# 49088        DonCess           0            0              0  ...
# 49089  BhanuAbhinawa           0            0              0  ...
# 49090        pungkas           0            0              4  ...
# 49091      riwatigis           0            0              0  ...
# 49092     taribetari           0            0              0  ...
#
#        Coordinates (Latitude)  Coordinates (Longitude) Place Hashtags  \
# 0                         NaN                      NaN  None     None
# 1                         NaN                      NaN  None     None
# 2                         NaN                      NaN  None     None
# 3                         NaN                      NaN  None     None
# 4                         NaN                      NaN  None     None
# ...                       ...                      ...   ...      ...
# 49088                     NaN                      NaN  None     None
# 49089                     NaN                      NaN  None     None
# 49090                     NaN                      NaN  None     None
# 49091                     NaN                      NaN  None     None
# 49092                     NaN                      NaN  None     None
#
#        Reply to User  Mentioned Users Count          Mentioned Users  \
# 0        txtdrimedia                      1            [txtdrimedia]
# 1               None                      0                     None
# 2      OposisiCerdas                      1          [OposisiCerdas]
# 3               None                      0                     None
# 4               None                      1        [AnthonyBudiawan]
# ...              ...                    ...                      ...
# 49088           None                      2         [pungkas, XL123]
# 49089           None                      2         [pungkas, XL123]
# 49090           None                      1                  [XL123]
# 49091           None                      1         [VietaAnggraini]
# 49092           None                      2  [chitraayu, tarrrriiii]
#
#       User Verified User Followers Count  User Statuses Count
# 0             False                   55                 5750
# 1             False                  366                 3179
# 2             False                   33                  882
# 3             False                  480                 5463
# 4             False                 1044                18130
# ...             ...                  ...                  ...
# 49088         False                 1077                19182
# 49089         False                  654                 9828
# 49090         False                 9478                31254
# 49091         False                 3509                66334
# 49092         False                  143                 4011
#
# [49093 rows x 24 columns]

# %%
data
# Out:
#                         Id  Search Keyword  \
# 0      1630518897362481153        PPN Naik
# 1      1630516734980669440        PPN Naik
# 2      1630503181120839682        PPN Naik
# 3      1630489345898708992        PPN Naik
# 4      1630486040556503041        PPN Naik
# ...                    ...             ...
# 49088          16667647720  Tarif baru PPN
# 49089          16667557518  Tarif baru PPN
# 49090          16667252573  Tarif baru PPN
# 49091           7671698988  Tarif baru PPN
# 49092           6075299212  Tarif baru PPN
#
#                                                      URL  \
# 0      https://twitter.com/Fakultas_meme/status/16305...
# 1      https://twitter.com/Nokomplen/status/163051673...
# 2      https://twitter.com/Aman47264904/status/163050...
# 3      https://twitter.com/buutiful_co/status/1630489...
# 4      https://twitter.com/rmbantencom/status/1630486...
# ...                                                  ...
# 49088     https://twitter.com/DonCess/status/16667647720
# 49089  https://twitter.com/BhanuAbhinawa/status/16667...
# 49090     https://twitter.com/pungkas/status/16667252573
# 49091    https://twitter.com/riwatigis/status/7671698988
# 49092   https://twitter.com/taribetari/status/6075299212
#
#                        Datetime  \
# 0     2023-02-28 10:42:53+00:00
# 1     2023-02-28 10:34:17+00:00
# 2     2023-02-28 09:40:26+00:00
# 3     2023-02-28 08:45:27+00:00
# 4     2023-02-28 08:32:19+00:00
# ...                         ...
# 49088 2010-06-21 04:05:52+00:00
# 49089 2010-06-21 04:04:15+00:00
# 49090 2010-06-21 03:59:05+00:00
# 49091 2010-01-12 15:11:04+00:00
# 49092 2009-11-26 07:17:53+00:00
#
#                                                    Tweet Sentiment Label  \
# 0      @txtdrimedia ketika L0Nte IMF menerbitkan glob...            None
# 1      Cook cook lah,,,, diampoot kabeehh!!! Kene ngo...            None
# 2      @OposisiCerdas Menurut anda aman??? tetapi efe...            None
# 3      Betul! My honeymoon masa tu negara still dlm f...            None
# 4      Pegawai Hidup Mewah, PPN, BBM Hingga Angka Kem...            None
# ...                                                  ...             ...
# 49088  RT @pungkas: BlackBerry Internet Service @XL12...            None
# 49089  RT @pungkas: BlackBerry Internet Service @XL12...            None
# 49090  BlackBerry Internet Service @XL123 turun tarif...            None
# 49091  wah tuh tarif PPN yang baru ya? RT @vietaanggr...            None
# 49092  Bnr2 tarif PPN.hahaRT @@chitraayu: @Tarrrriiii...            None
#
#             Username  View Count  Reply Count  Retweet Count  ...  \
# 0      Fakultas_meme          24            0              0  ...
# 1          Nokomplen           3            0              0  ...
# 2       Aman47264904           2            0              0  ...
# 3        buutiful_co          54            0              0  ...
# 4        rmbantencom          23            0              0  ...
# ...              ...         ...          ...            ...  ...
# 49088        DonCess           0            0              0  ...
# 49089  BhanuAbhinawa           0            0              0  ...
# 49090        pungkas           0            0              4  ...
# 49091      riwatigis           0            0              0  ...
# 49092     taribetari           0            0              0  ...
#
#        Coordinates (Latitude)  Coordinates (Longitude) Place Hashtags  \
# 0                         NaN                      NaN  None     None
# 1                         NaN                      NaN  None     None
# 2                         NaN                      NaN  None     None
# 3                         NaN                      NaN  None     None
# 4                         NaN                      NaN  None     None
# ...                       ...                      ...   ...      ...
# 49088                     NaN                      NaN  None     None
# 49089                     NaN                      NaN  None     None
# 49090                     NaN                      NaN  None     None
# 49091                     NaN                      NaN  None     None
# 49092                     NaN                      NaN  None     None
#
#        Reply to User  Mentioned Users Count          Mentioned Users  \
# 0        txtdrimedia                      1            [txtdrimedia]
# 1               None                      0                     None
# 2      OposisiCerdas                      1          [OposisiCerdas]
# 3               None                      0                     None
# 4               None                      1        [AnthonyBudiawan]
# ...              ...                    ...                      ...
# 49088           None                      2         [pungkas, XL123]
# 49089           None                      2         [pungkas, XL123]
# 49090           None                      1                  [XL123]
# 49091           None                      1         [VietaAnggraini]
# 49092           None                      2  [chitraayu, tarrrriiii]
#
#       User Verified User Followers Count  User Statuses Count
# 0             False                   55                 5750
# 1             False                  366                 3179
# 2             False                   33                  882
# 3             False                  480                 5463
# 4             False                 1044                18130
# ...             ...                  ...                  ...
# 49088         False                 1077                19182
# 49089         False                  654                 9828
# 49090         False                 9478                31254
# 49091         False                 3509                66334
# 49092         False                  143                 4011
#
# [49093 rows x 24 columns]
