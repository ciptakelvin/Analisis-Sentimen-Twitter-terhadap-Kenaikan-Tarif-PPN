# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sb
import random
from IPython.display import clear_output
import os

def clean_data():
    #Data Cleaner
    data=pd.read_csv('2023-02-28 19.36.57.730834 PPN Naik.csv')
    data=data.drop_duplicates(subset=["Tweet"])

    data=data.astype({
        'Id':'int64',
        'Datetime':'datetime64',
        'View Count':'int32',
        'Reply Count':'int32',
        'Retweet Count':'int32',
        'Like Count':'int32',
        'Quote Count':'int32',
        'Mentioned Users Count':'int32',
        'User Verified':'bool',
        'User Followers Count':'int32',
        'User Statuses Count':'int32',
        'User Verified':'bool'
    })

    data["Year"]=data["Datetime"].dt.year
    data["Month"]=data["Datetime"].dt.month
    data["Day"]=data["Datetime"].dt.day

    data["Kota"]=[str(i).split(",")[0] for i in data["Place"]]
    data.fillna(0)

    data=data[(data["Datetime"]<datetime(2022,12,31)) & (data["Datetime"]>datetime(2020,5,1))]
    data=data.drop(columns=["Sentiment Label"])
    data.to_csv('clean.csv',index=False)

def clear_labeled():
    if os.path.exists("labeled.csv"):
        os.remove("labeled.csv")
def labeler(data):
    
    #Labeler
    labeled_data=data.copy()
    if os.path.exists("labeled.csv"):
        saved_data=pd.read_csv("labeled.csv")
        labeled_data["Label"]=saved_data["Label"]
    else:
        labeled_data["Label"]=None
    while True:
        clear_output()
        location=random.randint(0,len(labeled_data)-1)
        print(str(labeled_data.iloc[location,4]))
        print("Input Sentiment 0:neutral 1:negative 2:positive 3:exit and save")
        new_sentiment=input()
        if new_sentiment=="3":
            break;
        elif new_sentiment=="0" or new_sentiment=="1" or new_sentiment=="2":
            labeled_data.iloc[location,27]=new_sentiment

    labeled_data.to_csv('labeled.csv',index=False)
    return pd.read_csv("labeled.csv")

# %%
# clean_data()
data=pd.read_csv("clean.csv")
# clear_labeled()
labeled=labeler(data)
labeled[labeled["Label"].notnull()]
# Out:
# @H1m4_W4r1 @prettymomratih @NdutChaniago @EJat3010 @sujud_wh @fadyanova Anak lonte komen gak pake otak.
# 1. PPN 11% kemana?
# 2. NPWP kemana?
# 3. Pajak PKB kemana?
# 4. Pajak PBB kemana?
# Masih banyak penerimaan negara dari rakyat
# Input Sentiment 0:neutral 1:negative 2:positive 3:exit and save
# 3
#                        Id Search Keyword  \
# 6030  1509707621401776131       PPN Naik
#
#                                                     URL             Datetime  \
# 6030  https://twitter.com/Muhzelandi/status/15097076...  2022-04-01 01:42:00
#
#                                                   Tweet    Username  \
# 6030  Fun fact!\nMulai 1 april ini:\n- Beberapa ruas...  Muhzelandi
#
#       View Count  Reply Count  Retweet Count  Like Count  ...  \
# 6030           0           13            103         310  ...
#
#       Mentioned Users Count Mentioned Users User Verified  \
# 6030                      0             NaN         False
#
#       User Followers Count  User Statuses Count  Year Month Day  Kota Label
# 6030                   331                22947  2022     4   1   NaN   0.0
#
# [1 rows x 28 columns]
