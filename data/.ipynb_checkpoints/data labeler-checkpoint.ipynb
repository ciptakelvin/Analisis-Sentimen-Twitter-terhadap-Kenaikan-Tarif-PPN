# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sb
import random
from IPython.display import clear_output
import os


def clear_labeled():
    if os.path.exists("labeled.csv"):
        os.remove("labeled.csv")

def labeler(data):
    
    #Labeler
    labeled_data=data.copy()
    if os.path.exists("labeled.csv"):
        saved_data=pd.read_csv("labeled.csv")
        labeled_data["Label"]=saved_data["Label"]
    else:
        labeled_data["Label"]=None
    while True:
        clear_output()
        location=random.randint(0,len(labeled_data)-1)
        print(str(labeled_data.iloc[location,4]))
        print("Input Sentiment 0:neutral 1:negative 2:positive 3:exit and save")
        new_sentiment=input()
        if new_sentiment=="3":
            break;
        elif new_sentiment=="0" or new_sentiment=="1" or new_sentiment=="2":
            labeled_data.loc[location,["Label"]]=new_sentiment

    labeled_data.to_csv('labeled.csv',index=False)
    return pd.read_csv("labeled.csv")

# %%
#Clear Labeled Data
# clear_labeled()

# %%
#Data Labeler
data=pd.read_csv('clean.csv')
labeled=labeler(data)
labeled[labeled["Label"].notnull()]
# Out:
# Kadin Dukung Sri Mulyani Naikkan PPN Jadi 11%, Tapi... - https://t.co/ebauTTzxHs
#
# #IDCORNER
# Input Sentiment 0:neutral 1:negative 2:positive 3:exit and save
# 3
#                         Id Search Keyword  \
# 268    1571500142473388033       PPN Naik
# 274    1571040948720902146       PPN Naik
# 356    1566411682754498560       PPN Naik
# 509    1557554902062141440       PPN Naik
# 646    1547774976354582528       PPN Naik
# ...                    ...            ...
# 26638  1400406794900369409   Kenaikan PPN
# 26731  1396737094152720386   Kenaikan PPN
# 26864  1392947599389323264   Kenaikan PPN
# 26903  1392356791564963841   Kenaikan PPN
# 26953  1392020622922772482   Kenaikan PPN
#
#                                                      URL             Datetime  \
# 268    https://twitter.com/susiloyhu/status/157150014...  2022-09-18 14:03:25
# 274    https://twitter.com/ernrntr/status/15710409487...  2022-09-17 07:38:45
# 356    https://twitter.com/MFatahillah_/status/156641...  2022-09-04 13:03:42
# 509    https://twitter.com/Nunjauhdisono/status/15575...  2022-08-11 02:30:01
# 646    https://twitter.com/ImminentDangers/status/154...  2022-07-15 02:48:05
# ...                                                  ...                  ...
# 26638  https://twitter.com/FirstMediaCares/status/140...  2021-06-03 10:59:32
# 26731  https://twitter.com/WikiDPR2/status/1396737094...  2021-05-24 07:57:28
# 26864  https://twitter.com/UsodoWiro/status/139294759...  2021-05-13 20:59:22
# 26903  https://twitter.com/DakwahMujahidah/status/139...  2021-05-12 05:51:42
# 26953  https://twitter.com/cnbcindonesia/status/13920...  2021-05-11 07:35:53
#
#                                                    Tweet         Username  \
# 268    @dapitdong hahahaaa tak terasa sdh hancur, dar...        susiloyhu
# 274    another insight is, PPN naik 12% di 2025 (klo ...          ernrntr
# 356    Ini bukan hanya soal BBM naik, harga pangan na...     MFatahillah_
# 509    @yashadipura @jokowi @mohmahfudmd jangan digan...    Nunjauhdisono
# 646    @Fitrinisa01 @jazadi @RamliRizal TOLOL.. bisa ...  ImminentDangers
# ...                                                  ...              ...
# 26638  @Dellaa01_ mengeluarkan investasi tambahan unt...  FirstMediaCares
# 26731  #Kom7 Dirjen Migas Kementerian ESDM RI : …adal...         WikiDPR2
# 26864  @tawajkt Tapi kenaikan PPN masih diterapkan ka...        UsodoWiro
# 26903  Rencana Kenaikan Tarif PPN\n\nMenteri Keuangan...  DakwahMujahidah
# 26953  Kenaikan tarif Pajak Pertambahan Nilai (PPN) y...    cnbcindonesia
#
#        View Count  Reply Count  Retweet Count  Like Count  ...  \
# 268             0            0              3           3  ...
# 274             0            1              0           0  ...
# 356             0            0              0           2  ...
# 509             0            0              0           1  ...
# 646             0            5              6          39  ...
# ...           ...          ...            ...         ...  ...
# 26638           0            0              0           0  ...
# 26731           0            0              0           0  ...
# 26864           0            0              0           1  ...
# 26903           0            0              0           0  ...
# 26953           0            2              4           0  ...
#
#                                 Mentioned Users User Verified  \
# 268                               ['dapitdong']         False
# 274                                         NaN         False
# 356                                         NaN         False
# 509    ['yashadipura', 'jokowi', 'mohmahfudmd']         False
# 646     ['Fitrinisa01', 'jazadi', 'RamliRizal']         False
# ...                                         ...           ...
# 26638                             ['Dellaa01_']          True
# 26731                                       NaN         False
# 26864                               ['tawajkt']         False
# 26903                                       NaN         False
# 26953                                       NaN          True
#
#       User Followers Count  User Statuses Count  Year Month Day Kota  \
# 268                   1515                25981  2022     9  18  NaN
# 274                    203                21934  2022     9  17  NaN
# 356                    226                 3899  2022     9   4  NaN
# 509                      3                 1402  2022     8  11  NaN
# 646                     98                 8949  2022     7  15  NaN
# ...                    ...                  ...   ...   ...  ..  ...
# 26638               239105              1405792  2021     6   3  NaN
# 26731                 3104               205200  2021     5  24  NaN
# 26864                 1163                55538  2021     5  13  NaN
# 26903                   76                 1367  2021     5  12  NaN
# 26953               198172               306834  2021     5  11  NaN
#
#                                                    Clean Label
# 268    hahahaaa tak terasa sudah hancur dari sektor e...   1.0
# 274    another insight is ppn naik di kalau tidak sal...   1.0
# 356    ini bukan hanya soal bbm naik harga pangan nai...   0.0
# 509    jangan diganti dibubarin aja makin banyak inst...   1.0
# 646    tolol bisa prediksi krismon ya hebat lah ketim...   1.0
# ...                                                  ...   ...
# 26638  mengeluarkan investasi tambahan untuk maintena...   0.0
# 26731  dirjen migas kementerian esdm ri adalah sebesa...   0.0
# 26864            tapi kenaikan ppn masih diterapkan kan    0.0
# 26903  rencana kenaikan tarif ppn menteri keuangan me...   0.0
# 26953  kenaikan tarif pajak pertambahan nilai ppn yan...   1.0
#
# [232 rows x 29 columns]

# %%
#Show Training Data
labeled=pd.read_csv('labeled.csv')
labeled=labeled[labeled["Label"].notnull()]
labeled=labeled.loc[:,["Tweet","Label"]]
labeled
# Out:
#                                                    Tweet  Label
# 268    @dapitdong hahahaaa tak terasa sdh hancur, dar...    1.0
# 274    another insight is, PPN naik 12% di 2025 (klo ...    1.0
# 356    Ini bukan hanya soal BBM naik, harga pangan na...    0.0
# 509    @yashadipura @jokowi @mohmahfudmd jangan digan...    1.0
# 646    @Fitrinisa01 @jazadi @RamliRizal TOLOL.. bisa ...    1.0
# ...                                                  ...    ...
# 26638  @Dellaa01_ mengeluarkan investasi tambahan unt...    0.0
# 26731  #Kom7 Dirjen Migas Kementerian ESDM RI : …adal...    0.0
# 26864  @tawajkt Tapi kenaikan PPN masih diterapkan ka...    0.0
# 26903  Rencana Kenaikan Tarif PPN\n\nMenteri Keuangan...    0.0
# 26953  Kenaikan tarif Pajak Pertambahan Nilai (PPN) y...    1.0
#
# [232 rows x 2 columns]
